# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle

# %%
data = pickle.load(file = open("dataset.pkl", "rb"))

# %%
X, y = data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
lr = RandomForestClassifier()
lr.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
y_pred = lr.predict(X)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      4737
#         True       0.79      0.32      0.46       263
#
#     accuracy                           0.96      5000
#    macro avg       0.88      0.66      0.72      5000
# weighted avg       0.95      0.96      0.95      5000

# %%
# %matplotlib inline

# %%
# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
ax.scatter(X[:,0], X[:,1], X[:,2], c=y, marker = "x")

# Set axis labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Set the title
ax.set_title('3D Scatter Plot')

# Show the plot
plt.show()

# %%
# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the scatter plot
ax.scatter(X[:,0], X[:,1], X[:,2], c=y+pred, marker = "x")

# Set axis labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Set the title
ax.set_title('3D Scatter Plot')

# Show the plot
plt.show()
# Out:
# 54
